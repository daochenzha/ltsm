# %%
import json
import matplotlib.pyplot as plt

root_path = './output/'
file_path = 'ltsm_train_large_lr1e-4_loraFalse_down540_freeze0_e2000'

with open(root_path+file_path+'/trainer_state.json', 'r') as file:
    data = json.load(file)


log_history = data.get('log_history', [])

filtered_log_history = [entry for entry in log_history if 'loss' in entry]

filtered_epochs = [entry['epoch'] for entry in filtered_log_history]
filtered_losses = [entry['loss'] for entry in filtered_log_history]

plt.figure(figsize=(10, 6))
plt.plot(filtered_epochs[10:], filtered_losses[10:], color='b')
plt.title(file_path)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.savefig(root_path+file_path+'/learning_curve.png')

# %%
import json
import matplotlib.pyplot as plt

root_path = './output/'
file_path = 'ltsm_train_large_lr1e-3_loraFalse_down540_freeze0_e2000'

with open(root_path+file_path+'/trainer_state.json', 'r') as file:
    data = json.load(file)


log_history = data.get('log_history', [])

filtered_log_history = [entry for entry in log_history if 'eval_loss' in entry]

filtered_epochs = [entry['epoch'] for entry in filtered_log_history]
filtered_losses = [entry['eval_loss'] for entry in filtered_log_history]

plt.figure(figsize=(10, 6))
plt.plot(filtered_epochs[10:], filtered_losses[10:], color='b')
plt.title(file_path)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.savefig(root_path+file_path+'/eval_learning_curve.png')

# %%
import pandas as pd

# 读取CSV文件
root_path = '/home/sl237/all_six_datasets/electricity/'
file_name = 'electricity'
df = pd.read_csv(root_path+file_name+'.csv')

# 遍历所有列
print(df.columns)
for column in df.columns[1:]:
    # 创建一个只包含当前列的新数据框
    df_column = df[[column]]
    
    # 保存当前列到CSV文件，文件名为test_列名.csv
    df_column.to_csv(f'{root_path+file_name}_{column}.csv', index=False)
# Out:
# Index(['date', '0', '1', '2', '3', '4', '5', '6', '7', '8',
#        ...
#        '311', '312', '313', '314', '315', '316', '317', '318', '319', 'OT'],
#       dtype='object', length=322)

# %%
import pandas as pd

# 读取CSV文件
root_path = '/home/sl237/all_six_datasets/traffic/'
file_name = 'traffic'
df = pd.read_csv(root_path+file_name+'.csv')

# 遍历所有列
print(df.columns)
for column in df.columns[1:]:
    # 创建一个只包含当前列的新数据框
    df_column = df[[column]]
    column_modified = column.replace('/', '-')
    # 保存当前列到CSV文件，文件名为test_列名.csv
    df_column.to_csv(f'{root_path+file_name}_{column_modified}.csv', index=False)
# Out:
# Index(['date', '0', '1', '2', '3', '4', '5', '6', '7', '8',
#        ...
#        '852', '853', '854', '855', '856', '857', '858', '859', '860', 'OT'],
#       dtype='object', length=863)

# %%
import pandas as pd

root_path = '/home/sl237/all_six_datasets/weather/'
file_name = 'weather'
df = pd.read_csv(root_path+file_name+'.csv')
cols = df.columns
df = df[cols[1:]]
# test = df.T.values.tolist()
df
# Out:
#        p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)
# 0       1008.89      0.71    273.18        -1.33    86.1          6.43  \
# 1       1008.76      0.75    273.22        -1.44    85.2          6.45
# 2       1008.66      0.73    273.21        -1.48    85.1          6.44
# 3       1008.64      0.37    272.86        -1.64    86.3          6.27
# 4       1008.61      0.33    272.82        -1.50    87.4          6.26
# ...         ...       ...       ...          ...     ...           ...
# 52691    978.32      2.28    277.16        -0.80    80.0          7.20
# 52692    978.30      2.13    277.01        -0.43    83.1          7.12
# 52693    978.26      1.99    276.88        -0.71    82.2          7.05
# 52694    978.26      2.07    276.95        -0.77    81.4          7.09
# 52695    978.24      2.01    276.89        -0.66    82.4          7.06
#
#        VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  ...  wv (m/s)
# ...

# %%
import pandas as pd
root_path = '/home/sl237/all_six_datasets/weather/weather.csv'
df_data = pd.read_csv(root_path)
cols = df_data.columns[1:]
raw_data = df_data[cols].T.values
# len(raw_data),len(raw_data[0])

# %%
print(raw_data.shape)
print(raw_data[0].shape)
# Out:
# (21, 52696)
# (52696,)

# %%
import numpy as np
list_data = raw_data.tolist()
np_data = np.array(list_data)
print(type(np_data), type(np_data[0]), type(np_data[0][0]))
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.float64'>

# %%
len(test),len(test[1])
i = 0
for index, sequence in zip(df.columns[1:], test):
    index = index.replace('/','-')
    print(index, len(sequence))

    i += 1
    if i > 10:
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 len(test),len(test[1])
#       2 i = 0
#       3 for index, sequence in zip(df.columns[1:], test):
#
# NameError: name 'test' is not defined

# %%
import os
import os
# dir_name = os.path.split(os.path.dirname(root_path+file_name))[-1]
# dir_name
root_path = '/home/sl237/all_six_datasets/weather/weather.csv'

file_extension = root_path.split('/')[-2]+'/'+root_path.split('/')[-1].split('.')[0]
file_extension
# Out:
# 'weather/weather'

# %%
pt = "/home/gw22/python_project/ltsm_proj/ltsm/prompt/prompt_data_normalize_csv"
root_path = '/home/sl237/all_six_datasets/weather/weather.csv'

file_extension = root_path.split('/')[-2]+'/'+root_path.split('/')[-1].split('.')[0]
import torch
import os
for col in cols:
    pt_path = os.path.join(pt, file_extension+ "_"+str(col)+"_prompt.pth.tar")
    data = torch.load(pt_path)
    print(data.T[0])
    data = data.T[0]
    prompt_data = [ data.iloc[i] for i in range(len(data)) ]
    print(prompt_data)
    print(len(prompt_data))    
    break
# Out:
# 0     -0.086515
# 1      0.269108
# 2     -0.086515
# 3     -0.078737
# 4      1.426284
#          ...
# 128   -0.080035
# 129   -0.079697
# 130   -0.079391
# 131   -0.079193
# 132   -0.386069
# Name: 0, Length: 133, dtype: float64
# ...
